# %% [markdown]
# ### Script to Read WSIs and XML(Masks) of each nuclei type
# ### Created by Taimoor Shakeel
#
# This code will create separate folder for each patient and subfolders for annotated images.
#
# Each sub-folder corresponding to sub-images under each patient will contain 4 sub-sub-folders (Epithelial, Lymphocyte, Neutrophil and Macrophage) to save indviudal corresponding binary-masks with value 255 for each cell-type and background 0
#
# ### Input
# data_path: Specify the path of downloaded images
#
# destination_path = Specify the path to save corresponding binary masks
#
# ### Output
# MoNuSAC_masks directory in the destination_path
#
# Binary masks will be saved in each sub-sub-folder
#
# Folder -- Patient name
#
# Sub-folder -- Sub-images under each patient
#
# Sub-Sub-folder -- Annotated cell-type on each sub-image

# %%
#Process whole slide images

import os
os.environ['PATH'] = "C:/Users/Administrator/Downloads/openslide-win64-20160612/openslide-win64-20160612/bin" + ";" + os.environ['PATH']
import openslide
#from openslide import open_slide # http://openslide.org/api/python/

import os
from xml.dom import minidom
import numpy as np
from openslide import open_slide  
from glob import glob
import cv2
import matplotlib.pyplot as plt
import scipy.io as sio
from PIL import Image
import scipy
import scipy.ndimage
from shapely.geometry import Polygon
from skimage import draw
import xml.etree.ElementTree as ET

# %%
def create_directory(directory):
    '''
    Creates a new folder in the specified directory if the folder doesn't exist.
    INPUT
        directory: Folder to be created, called as "folder/".
    OUTPUT
        New folder in the current directory.
    '''
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
# Read svs files from the desired path
count = 0

Organ = "Breast"
# Organ = "Lung"
# Organ = "Kidney"
# Organ = "Prostate"

main = "D://Taimoor_Datasets/Thesis/Nuclei/MoNuSAC/Training_Data/"

destination_path = os.path.join(main) # Path to save binary masks corresponding to xml files

# Target path
# Path to annotations
data_path = os.path.join(main, "Images_&_Annotations_Organ/", str(Organ)) #Path to read data from

try:
    # Make directory
    create_directory(data_path)
    # Change root path
    os.chdir(data_path)#Create folder named as MoNuSAC_masks
except OSError:
    print ("Creation of the images and annotations directory %s failed" % data_path)

    
    
# Target path
# Path to annotations
mask_path = os.path.join(main, "Masks_Organ/", str(Organ)) #Path to read data from and Path to save binary masks corresponding to xml files

try:
    # Make directory
    create_directory(mask_path)
    # Change root path
    os.chdir(mask_path)#Create folder named as MoNuSAC_masks
except OSError:
    print ("Creation of the mask directory %s failed" % mask_path)
    

    
patients = [x[0] for x in os.walk(data_path)]#Total patients in the data_path

print('\n')
print('---'*35)
print('Main Folders')

print(destination_path)
print(data_path)
print(mask_path)
print(len(patients))
print('---'*35)
# Out:
# ---------------------------------------------------------------------------------------------------------
# Main Folders
# D://Taimoor_Datasets/Thesis/Nuclei/MoNuSAC/Training_Data/
# D://Taimoor_Datasets/Thesis/Nuclei/MoNuSAC/Training_Data/Images_&_Annotations_Organ/Breast
# D://Taimoor_Datasets/Thesis/Nuclei/MoNuSAC/Training_Data/Masks_Organ/Breast
# 11
# ---------------------------------------------------------------------------------------------------------

# %%
for patient_loc in patients[:]:
# for patient_loc in patients[9:]:
    patient_name = patient_loc[len(data_path)+1:]#Patient name
    print(patient_name)
    
    ## To make patient's name directory in the destination folder
    try:
        os.mkdir(patient_name)
    except OSError:
        print ("\n Creation of the patient's directory %s failed" % patient_name)
        
    ## Read sub-images of each patient in the data path        
    sub_images = glob(patient_loc+'/*.svs')
    for sub_image_loc in sub_images:
        sub_image_name = sub_image_loc[len(data_path)+len(patient_name)+1:-4]        
        print(sub_image_name)
        
        ## To make sub_image directory under the patient's folder
        sub_image = './'+patient_name+'/'+sub_image_name #Destination path
        try:
            os.mkdir(sub_image)
        except OSError:
            print ("\n Creation of the patient's directory %s failed" % sub_image)
            
        image_name = sub_image_loc
        img = openslide.OpenSlide(image_name)
                                  
        # Read xml file
        xml_file_name  = image_name[:-4]
        xml_file_name = xml_file_name+'.xml'
        tree = ET.parse(xml_file_name)
        root = tree.getroot()
        
        #Generate binary mask for each cell-type                         
        for k in range(len(root)):
            label = [x.attrib['Name'] for x in root[k][0]]
            label = label[0]
            
            for child in root[k]:
                for x in child:
                    r = x.tag
                    if r == 'Attribute':
                        count = count+1
                        print(count)
                        label = x.attrib['Name']
                        binary_mask = np.transpose(np.zeros((img.read_region((0,0),0,img.level_dimensions[0]).size))) 
                        print(label)
                        
                        # Create directory for each label
                        sub_path = sub_image+'/'+label
                        
                        try:
                            os.mkdir(sub_path)
                        except OSError:
                            print ("Creation of the directory %s failed" % label)
                        else:
                            print ("Successfully created the directory %s " % label) 
                                          
                        
                    if r == 'Region':
                        regions = []
                        vertices = x[1]
                        coords = np.zeros((len(vertices), 2))
                        for i, vertex in enumerate(vertices):
                            coords[i][0] = vertex.attrib['X']
                            coords[i][1] = vertex.attrib['Y']        
                        regions.append(coords)
                        poly = Polygon(regions[0])  
                        
                        vertex_row_coords = regions[0][:,0]
                        vertex_col_coords = regions[0][:,1]
                        fill_row_coords, fill_col_coords = draw.polygon(vertex_col_coords, vertex_row_coords, binary_mask.shape)
                        binary_mask[fill_row_coords, fill_col_coords] = 255
                        mask_path = sub_path+'/'+str(count)+'_mask.tif'
                        cv2.imwrite(mask_path, binary_mask)
# Out:
# TCGA-A2-A0CV-01Z-00-DX1
# \TCGA-A2-A0CV-01Z-00-DX1_1
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_1
# 461
# Epithelial
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_1/Epithelial
# 462
# Lymphocyte
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_1/Lymphocyte
# 463
# Neutrophil
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_1/Neutrophil
# 464
# Macrophage
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_1/Macrophage
# \TCGA-A2-A0CV-01Z-00-DX1_2
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_2
# 465
# Epithelial
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_2/Epithelial
# 466
# Lymphocyte
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_2/Lymphocyte
# 467
# Neutrophil
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_2/Neutrophil
# 468
# Macrophage
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_2/Macrophage
# \TCGA-A2-A0CV-01Z-00-DX1_3
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_3
# 469
# Epithelial
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_3/Epithelial
# 470
# Lymphocyte
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_3/Lymphocyte
# 471
# Neutrophil
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_3/Neutrophil
# 472
# Macrophage
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_3/Macrophage
# \TCGA-A2-A0CV-01Z-00-DX1_4
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_4
# 473
# Epithelial
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_4/Epithelial
# 474
# Lymphocyte
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_4/Lymphocyte
# 475
# Neutrophil
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_4/Neutrophil
# 476
# Macrophage
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_4/Macrophage
# \TCGA-A2-A0CV-01Z-00-DX1_5
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_5
# 477
# Epithelial
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_5/Epithelial
# 478
# Lymphocyte
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_5/Lymphocyte
# 479
# Neutrophil
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_5/Neutrophil
# 480
# Macrophage
# ./TCGA-A2-A0CV-01Z-00-DX1/\TCGA-A2-A0CV-01Z-00-DX1_5/Macrophage
# TCGA-A2-A0ES-01Z-00-DX1
# \TCGA-A2-A0ES-01Z-00-DX1_1
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_1
# 481
# Epithelial
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_1/Epithelial
# 482
# Lymphocyte
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_1/Lymphocyte
# 483
# Neutrophil
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_1/Neutrophil
# 484
# Macrophage
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_1/Macrophage
# \TCGA-A2-A0ES-01Z-00-DX1_2
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_2
# 485
# Epithelial
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_2/Epithelial
# 486
# Lymphocyte
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_2/Lymphocyte
# 487
# Neutrophil
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_2/Neutrophil
# 488
# Macrophage
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_2/Macrophage
# \TCGA-A2-A0ES-01Z-00-DX1_3
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_3
# 489
# Epithelial
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_3/Epithelial
# 490
# Lymphocyte
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_3/Lymphocyte
# 491
# Neutrophil
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_3/Neutrophil
# 492
# Macrophage
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_3/Macrophage
# \TCGA-A2-A0ES-01Z-00-DX1_4
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_4
# 493
# Epithelial
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_4/Epithelial
# 494
# Lymphocyte
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_4/Lymphocyte
# 495
# Neutrophil
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_4/Neutrophil
# 496
# Macrophage
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_4/Macrophage
# \TCGA-A2-A0ES-01Z-00-DX1_5
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_5
# 497
# Epithelial
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_5/Epithelial
# 498
# Lymphocyte
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_5/Lymphocyte
# 499
# Neutrophil
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_5/Neutrophil
# 500
# Macrophage
# ./TCGA-A2-A0ES-01Z-00-DX1/\TCGA-A2-A0ES-01Z-00-DX1_5/Macrophage
# TCGA-B6-A0WZ-01Z-00-DX1
# \TCGA-B6-A0WZ-01Z-00-DX1_1
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_1
# 501
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_1/Epithelial
# 502
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_1/Lymphocyte
# 503
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_1/Neutrophil
# 504
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_1/Macrophage
# \TCGA-B6-A0WZ-01Z-00-DX1_2
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_2
# 505
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_2/Epithelial
# 506
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_2/Lymphocyte
# 507
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_2/Neutrophil
# 508
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_2/Macrophage
# \TCGA-B6-A0WZ-01Z-00-DX1_3
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_3
# 509
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_3/Epithelial
# 510
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_3/Lymphocyte
# 511
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_3/Neutrophil
# 512
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_3/Macrophage
# \TCGA-B6-A0WZ-01Z-00-DX1_4
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_4
# 513
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_4/Epithelial
# 514
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_4/Lymphocyte
# 515
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_4/Neutrophil
# 516
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_4/Macrophage
# \TCGA-B6-A0WZ-01Z-00-DX1_5
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_5
# 517
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_5/Epithelial
# 518
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_5/Lymphocyte
# 519
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_5/Neutrophil
# 520
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_5/Macrophage
# \TCGA-B6-A0WZ-01Z-00-DX1_6
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_6
# 521
# Epithelial
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_6/Epithelial
# 522
# Lymphocyte
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_6/Lymphocyte
# 523
# Neutrophil
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_6/Neutrophil
# 524
# Macrophage
# ./TCGA-B6-A0WZ-01Z-00-DX1/\TCGA-B6-A0WZ-01Z-00-DX1_6/Macrophage
# TCGA-BH-A18T-01Z-00-DX1
# \TCGA-BH-A18T-01Z-00-DX1_1
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_1
# 525
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_1/Epithelial
# 526
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_1/Lymphocyte
# 527
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_1/Neutrophil
# 528
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_1/Macrophage
# \TCGA-BH-A18T-01Z-00-DX1_2
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_2
# 529
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_2/Epithelial
# 530
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_2/Lymphocyte
# 531
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_2/Neutrophil
# 532
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_2/Macrophage
# \TCGA-BH-A18T-01Z-00-DX1_3
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_3
# 533
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_3/Epithelial
# 534
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_3/Lymphocyte
# 535
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_3/Neutrophil
# 536
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_3/Macrophage
# \TCGA-BH-A18T-01Z-00-DX1_4
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_4
# 537
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_4/Epithelial
# 538
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_4/Lymphocyte
# 539
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_4/Neutrophil
# 540
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_4/Macrophage
# \TCGA-BH-A18T-01Z-00-DX1_5
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_5
# 541
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_5/Epithelial
# 542
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_5/Lymphocyte
# 543
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_5/Neutrophil
# 544
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_5/Macrophage
# \TCGA-BH-A18T-01Z-00-DX1_6
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_6
# 545
# Epithelial
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_6/Epithelial
# 546
# Lymphocyte
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_6/Lymphocyte
# 547
# Neutrophil
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_6/Neutrophil
# 548
# Macrophage
# ./TCGA-BH-A18T-01Z-00-DX1/\TCGA-BH-A18T-01Z-00-DX1_6/Macrophage
# TCGA-D8-A1X5-01Z-00-DX2
# \TCGA-D8-A1X5-01Z-00-DX2_1
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_1
# 549
# Epithelial
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_1/Epithelial
# 550
# Lymphocyte
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_1/Lymphocyte
# 551
# Neutrophil
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_1/Neutrophil
# 552
# Macrophage
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_1/Macrophage
# \TCGA-D8-A1X5-01Z-00-DX2_2
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_2
# 553
# Epithelial
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_2/Epithelial
# 554
# Lymphocyte
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_2/Lymphocyte
# 555
# Neutrophil
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_2/Neutrophil
# 556
# Macrophage
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_2/Macrophage
# \TCGA-D8-A1X5-01Z-00-DX2_3
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_3
# 557
# Epithelial
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_3/Epithelial
# 558
# Lymphocyte
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_3/Lymphocyte
# 559
# Neutrophil
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_3/Neutrophil
# 560
# Macrophage
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_3/Macrophage
# \TCGA-D8-A1X5-01Z-00-DX2_4
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_4
# 561
# Epithelial
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_4/Epithelial
# 562
# Lymphocyte
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_4/Lymphocyte
# 563
# Description
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_4/Description
# 564
# Macrophage
# ./TCGA-D8-A1X5-01Z-00-DX2/\TCGA-D8-A1X5-01Z-00-DX2_4/Macrophage
# TCGA-E2-A154-01Z-00-DX1
# \TCGA-E2-A154-01Z-00-DX1_1
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_1
# 565
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_1/Epithelial
# 566
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_1/Lymphocyte
# 567
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_1/Neutrophil
# 568
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_1/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_2
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_2
# 569
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_2/Epithelial
# 570
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_2/Lymphocyte
# 571
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_2/Neutrophil
# 572
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_2/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_3
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_3
# 573
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_3/Epithelial
# 574
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_3/Lymphocyte
# 575
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_3/Neutrophil
# 576
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_3/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_4
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_4
# 577
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_4/Epithelial
# 578
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_4/Lymphocyte
# 579
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_4/Neutrophil
# 580
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_4/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_5
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_5
# 581
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_5/Epithelial
# 582
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_5/Lymphocyte
# 583
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_5/Neutrophil
# 584
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_5/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_6
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_6
# 585
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_6/Epithelial
# 586
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_6/Lymphocyte
# 587
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_6/Neutrophil
# 588
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_6/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_7
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_7
# 589
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_7/Epithelial
# 590
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_7/Lymphocyte
# 591
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_7/Neutrophil
# 592
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_7/Macrophage
# \TCGA-E2-A154-01Z-00-DX1_8
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_8
# 593
# Epithelial
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_8/Epithelial
# 594
# Lymphocyte
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_8/Lymphocyte
# 595
# Neutrophil
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_8/Neutrophil
# 596
# Macrophage
# ./TCGA-E2-A154-01Z-00-DX1/\TCGA-E2-A154-01Z-00-DX1_8/Macrophage
# TCGA-E9-A22B-01Z-00-DX1
# \TCGA-E9-A22B-01Z-00-DX1_1
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_1
# 597
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_1/Epithelial
# 598
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_1/Lymphocyte
# 599
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_1/Neutrophil
# 600
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_1/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_2
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_2
# 601
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_2/Epithelial
# 602
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_2/Lymphocyte
# 603
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_2/Neutrophil
# 604
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_2/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_3
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_3
# 605
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_3/Epithelial
# 606
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_3/Lymphocyte
# 607
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_3/Neutrophil
# 608
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_3/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_4
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_4
# 609
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_4/Epithelial
# 610
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_4/Lymphocyte
# 611
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_4/Neutrophil
# 612
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_4/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_5
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_5
# 613
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_5/Epithelial
# 614
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_5/Lymphocyte
# 615
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_5/Neutrophil
# 616
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_5/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_6
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_6
# 617
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_6/Epithelial
# 618
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_6/Lymphocyte
# 619
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_6/Neutrophil
# 620
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_6/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_7
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_7
# 621
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_7/Epithelial
# 622
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_7/Lymphocyte
# 623
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_7/Neutrophil
# 624
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_7/Macrophage
# \TCGA-E9-A22B-01Z-00-DX1_8
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_8
# 625
# Epithelial
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_8/Epithelial
# 626
# Lymphocyte
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_8/Lymphocyte
# 627
# Neutrophil
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_8/Neutrophil
# 628
# Macrophage
# ./TCGA-E9-A22B-01Z-00-DX1/\TCGA-E9-A22B-01Z-00-DX1_8/Macrophage
# TCGA-E9-A22G-01Z-00-DX1
# \TCGA-E9-A22G-01Z-00-DX1_1
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_1
# 629
# Epithelial
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_1/Epithelial
# 630
# Lymphocyte
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_1/Lymphocyte
# 631
# Neutrophil
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_1/Neutrophil
# 632
# Macrophage
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_1/Macrophage
# \TCGA-E9-A22G-01Z-00-DX1_2
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_2
# 633
# Epithelial
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_2/Epithelial
# 634
# Lymphocyte
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_2/Lymphocyte
# 635
# Neutrophil
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_2/Neutrophil
# 636
# Macrophage
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_2/Macrophage
# \TCGA-E9-A22G-01Z-00-DX1_3
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_3
# 637
# Epithelial
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_3/Epithelial
# 638
# Lymphocyte
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_3/Lymphocyte
# 639
# Neutrophil
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_3/Neutrophil
# 640
# Macrophage
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_3/Macrophage
# \TCGA-E9-A22G-01Z-00-DX1_4
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_4
# 641
# Epithelial
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_4/Epithelial
# 642
# Lymphocyte
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_4/Lymphocyte
# 643
# Neutrophil
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_4/Neutrophil
# 644
# Macrophage
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_4/Macrophage
# \TCGA-E9-A22G-01Z-00-DX1_5
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_5
# 645
# Epithelial
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_5/Epithelial
# 646
# Lymphocyte
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_5/Lymphocyte
# 647
# Neutrophil
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_5/Neutrophil
# 648
# Macrophage
# ./TCGA-E9-A22G-01Z-00-DX1/\TCGA-E9-A22G-01Z-00-DX1_5/Macrophage
# TCGA-EW-A6SD-01Z-00-DX1
# \TCGA-EW-A6SD-01Z-00-DX1_1
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_1
# 649
# Epithelial
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_1/Epithelial
# 650
# Lymphocyte
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_1/Lymphocyte
# 651
# Neutrophil
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_1/Neutrophil
# 652
# Macrophage
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_1/Macrophage
# \TCGA-EW-A6SD-01Z-00-DX1_2
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_2
# 653
# Epithelial
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_2/Epithelial
# 654
# Lymphocyte
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_2/Lymphocyte
# 655
# Neutrophil
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_2/Neutrophil
# 656
# Macrophage
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_2/Macrophage
# \TCGA-EW-A6SD-01Z-00-DX1_3
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_3
# 657
# Epithelial
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_3/Epithelial
# 658
# Lymphocyte
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_3/Lymphocyte
# 659
# Neutrophil
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_3/Neutrophil
# 660
# Macrophage
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_3/Macrophage
# \TCGA-EW-A6SD-01Z-00-DX1_4
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_4
# 661
# Epithelial
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_4/Epithelial
# 662
# Lymphocyte
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_4/Lymphocyte
# 663
# Neutrophil
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_4/Neutrophil
# 664
# Macrophage
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_4/Macrophage
# \TCGA-EW-A6SD-01Z-00-DX1_5
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_5
# 665
# Epithelial
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_5/Epithelial
# 666
# Lymphocyte
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_5/Lymphocyte
# 667
# Neutrophil
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_5/Neutrophil
# 668
# Macrophage
# ./TCGA-EW-A6SD-01Z-00-DX1/\TCGA-EW-A6SD-01Z-00-DX1_5/Macrophage
# TCGA-S3-AA11-01Z-00-DX1
# \TCGA-S3-AA11-01Z-00-DX1_1
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_1
# 669
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_1/Epithelial
# 670
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_1/Lymphocyte
# 671
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_1/Neutrophil
# 672
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_1/Macrophage
# \TCGA-S3-AA11-01Z-00-DX1_2
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_2
# 673
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_2/Epithelial
# 674
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_2/Lymphocyte
# 675
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_2/Neutrophil
# 676
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_2/Macrophage
# \TCGA-S3-AA11-01Z-00-DX1_3
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_3
# 677
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_3/Epithelial
# 678
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_3/Lymphocyte
# 679
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_3/Neutrophil
# 680
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_3/Macrophage
# \TCGA-S3-AA11-01Z-00-DX1_4
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_4
# 681
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_4/Epithelial
# 682
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_4/Lymphocyte
# 683
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_4/Neutrophil
# 684
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_4/Macrophage
# \TCGA-S3-AA11-01Z-00-DX1_5
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_5
# 685
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_5/Epithelial
# 686
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_5/Lymphocyte
# 687
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_5/Neutrophil
# 688
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_5/Macrophage
# \TCGA-S3-AA11-01Z-00-DX1_6
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_6
# 689
# Epithelial
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_6/Epithelial
# 690
# Lymphocyte
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_6/Lymphocyte
# 691
# Neutrophil
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_6/Neutrophil
# 692
# Macrophage
# ./TCGA-S3-AA11-01Z-00-DX1/\TCGA-S3-AA11-01Z-00-DX1_6/Macrophage
